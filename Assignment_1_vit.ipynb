# %% [markdown]
# <a href="https://colab.research.google.com/github/smartinternz02/SI-GuidedProject-581984-1694712059/blob/main/Assignment_1_vit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
#Task 1
df = pd.DataFrame()
df[0]=np.random.randint(15,250,4)
df[1]=np.random.randint(15,250,4)
df[2]=np.random.randint(15,250,4)
df[3]=np.random.randint(15,250,4)
df
# Out:
#      0    1    2    3
# 0  227  203   83  122
# 1   46  159  176   35
# 2  177   66  181   37
# 3  125  148  192   54

# %%
#Task 2
df.columns = ['Random value 1','Random value 2','Random value 3','Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0             227             203              83             122
# 1              46             159             176              35
# 2             177              66             181              37
# 3             125             148             192              54

# %%
#Task 3
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean       143.750000      144.000000      158.000000       62.000000
# std         77.336386       57.172254       50.444689       40.898248
# min         46.000000       66.000000       83.000000       35.000000
# 25%        105.250000      127.500000      152.750000       36.500000
# 50%        151.000000      153.500000      178.500000       45.500000
# 75%        189.500000      170.000000      183.750000       71.000000
# max        227.000000      203.000000      192.000000      122.000000

# %%
#Task 4
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Random value 1  4 non-null      int64
#  1   Random value 2  4 non-null      int64
#  2   Random value 3  4 non-null      int64
#  3   Random value 4  4 non-null      int64
# dtypes: int64(4)
# memory usage: 256.0 bytes

# %%
#Task 5
print('Using location method')
print(df.loc[:,'Random value 2'])
print(df.loc[:,'Random value 3'])
print('Using index location method')
print(df.iloc[:,1])
print(df.iloc[:,2])
# Out:
# Using location method
# 0    203
# 1    159
# 2     66
# 3    148
# Name: Random value 2, dtype: int64
# 0     83
# 1    176
# 2    181
# 3    192
# Name: Random value 3, dtype: int64
# Using index location method
# 0    203
# 1    159
# 2     66
# 3    148
# Name: Random value 2, dtype: int64
# 0     83
# 1    176
# 2    181
# 3    192
# Name: Random value 3, dtype: int64
